# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import re
import plotly.graph_objs as go
import plotly.express as px
from scipy.stats import gaussian_kde

file_path = 'base/PEDE_PASSOS_DATASET_FIAP.csv'
pd.set_option('display.max_columns', None)
df = pd.read_csv(file_path, delimiter=';')

# %% [markdown]
# # Analisando os dados 🔎

# %%
# Tem algumas inconsistências de nomenclatura em relação ao dataset e o PDF de dicionário, mas acho que tudo bem...
# Reparei também que temos colunas faltando, sendo elas: **REC_PSICO_2021**, **REC_PSICO_2022** e **INSTITUICAO_ENSINO_ALUNO_2022**.

# %% [markdown]
# **Essa linha demonstra que o Aluno foi ingressado em 2022, e todas as outras colunas são nulas. Uma recomendação seria criar para cada ano um dataset separado para início das análises.** 🤔

# %%
pd.DataFrame(df.loc[df['NOME'] == 'ALUNO-2']).transpose().T
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 1                           NaN  ALUNO-2              NaN          NaN
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020 INDE_2020 INDE_CONCEITO_2020 PEDRA_2020  \
# 1             NaN               NaN       NaN                NaN        NaN
#
#   DESTAQUE_IEG_2020 DESTAQUE_IDA_2020 DESTAQUE_IPV_2020 IAA_2020 IEG_2020  \
# 1               NaN               NaN               NaN      NaN      NaN
#
#   IPS_2020 IDA_2020 IPP_2020 IPV_2020 IAN_2020 FASE_2021 TURMA_2021  \
# 1      NaN      NaN      NaN      NaN      NaN       NaN        NaN
#
#   INSTITUICAO_ENSINO_ALUNO_2021 SINALIZADOR_INGRESSANTE_2021 PEDRA_2021  \
# 1                           NaN                          NaN        NaN
#
#   INDE_2021 IAA_2021 IEG_2021 IPS_2021 IDA_2021 IPP_2021 REC_EQUIPE_1_2021  \
# 1       NaN      NaN      NaN      NaN      NaN      NaN               NaN
#
#   REC_EQUIPE_2_2021 REC_EQUIPE_3_2021 REC_EQUIPE_4_2021 PONTO_VIRADA_2021  \
# 1               NaN               NaN               NaN               NaN
#
#   IPV_2021 IAN_2021 NIVEL_IDEAL_2021 DEFASAGEM_2021 FASE_2022 TURMA_2022  \
# 1      NaN      NaN              NaN            NaN       0.0          K
#
#   ANO_INGRESSO_2022 BOLSISTA_2022 INDE_2022 CG_2022 CF_2022 CT_2022  \
# 1            2022.0           Não  7.675509   245.0    66.0     6.0
#
#   PEDRA_2022                                DESTAQUE_IEG_2022  \
# 1   Ametista  Destaque: A sua boa entrega das lições de casa.
#
#                                  DESTAQUE_IDA_2022  \
# 1  Destaque: As suas boas notas na Passos Mágicos.
#
#                                    DESTAQUE_IPV_2022  IAA_2022  IEG_2022  \
# 1  Destaque: A sua boa integração aos Princípios ...  10.00002  7.581705
#
#   IPS_2022  IDA_2022 NOTA_PORT_2022 NOTA_MAT_2022 NOTA_ING_2022 QTD_AVAL_2022  \
# 1      7.5  8.816667            8.2      9.433333           NaN           2.0
#
#   IPP_2022           REC_AVA_1_2022         REC_AVA_2_2022 REC_AVA_3_2022  \
# 1    5.625  Mantido na Fase + Bolsa  Mantido na Fase atual            NaN
#
#   REC_AVA_4_2022 INDICADO_BOLSA_2022 PONTO_VIRADA_2022  IPV_2022 IAN_2022  \
# 1            NaN                 Sim               Não  7.916665      5.0
#
#        NIVEL_IDEAL_2022
# 1  Fase 2 (5º e 6º ano)

# %%
df.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 0                Escola Pública  ALUNO-1               11            2
# 1                           NaN  ALUNO-2              NaN          NaN
# 2                Escola Pública  ALUNO-3               12            2
# 3                Escola Pública  ALUNO-4               10            2
# 4                Escola Pública  ALUNO-5               10            1
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020          INDE_2020 INDE_CONCEITO_2020  \
# 0              2H               Não           7.883752                  B
# 1             NaN               NaN                NaN                NaN
# 2              3H               Não  7.856389666666666                  B
# 3              1D               Não           5.076252                  D
# 4              2M               Não           8.077085                  B
#
#   PEDRA_2020                                  DESTAQUE_IEG_2020  \
# 0   Ametista  Seu destaque em 2020: A sua boa entrega das li...
# 1        NaN                                                NaN
# 2   Ametista  Seu destaque em 2020: A sua boa entrega das li...
# 3    Quartzo  Ponto a melhorar em 2021: Melhorar a sua entre...
# 4   Ametista  Seu destaque em 2020: A sua boa entrega das li...
#
#                                    DESTAQUE_IDA_2020  \
# 0  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 1                                                NaN
# 2  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 3  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 4  Seu destaque em 2020: As suas boas notas na Pa...
#
#                                    DESTAQUE_IPV_2020           IAA_2020  \
# 0  Seu destaque em 2020: A sua boa integração aos...  8.500020000000001
# 1                                                NaN                NaN
# 2  Seu destaque em 2020: A sua boa integração aos...            7.91667
# 3  Ponto a melhorar em 2021: Integrar-se mais aos...  8.000020000000001
# 4  Seu destaque em 2020: A sua boa integração aos...            7.50002
#
#   IEG_2020 IPS_2020 IDA_2020 IPP_2020           IPV_2020 IAN_2020  FASE_2021  \
# 0      8.7      7.5        7   5.9375               7.75       10        2.0
# 1      NaN      NaN      NaN      NaN                NaN      NaN        NaN
# 2      8.9      7.5      5.5    8.125  8.111113333333334       10        3.0
# 3      4.1    6.875        0   7.1875               7.75        5        NaN
# 4        8      7.5      7.5   8.4375           8.166665       10        2.0
#
#   TURMA_2021 INSTITUICAO_ENSINO_ALUNO_2021 SINALIZADOR_INGRESSANTE_2021  \
# 0          G                  Rede Decisão                  Ingressante
# 1        NaN                           NaN                          NaN
# 2          F                Escola Pública                     Veterano
# 3        NaN                           NaN                          NaN
# 4          L                Escola Pública                     Veterano
#
#   PEDRA_2021 INDE_2021  IAA_2021  IEG_2021  IPS_2021  IDA_2021  IPP_2021  \
# 0   Ametista     7.319       7.5       6.3       6.9       8.8       7.7
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2   Ametista     7.021       7.1       6.9       6.3       5.6       7.3
# 3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4   Ametista     7.399       7.4       7.5       7.5       5.4       8.5
#
#    REC_EQUIPE_1_2021      REC_EQUIPE_2_2021      REC_EQUIPE_3_2021  \
# 0  Promovido de Fase      Promovido de Fase  Mantido na Fase atual
# 1                NaN                    NaN                    NaN
# 2  Promovido de Fase      Promovido de Fase  Mantido na Fase atual
# 3                NaN                    NaN                    NaN
# 4  Promovido de Fase  Mantido na Fase atual  Mantido na Fase atual
#
#   REC_EQUIPE_4_2021 PONTO_VIRADA_2021  IPV_2021  IAN_2021  \
# 0      Não avaliado               Não       8.1       5.0
# 1               NaN               NaN       NaN       NaN
# 2      Não avaliado               Não       7.2      10.0
# 3               NaN               NaN       NaN       NaN
# 4      Não avaliado               Não       7.4      10.0
#
#         NIVEL_IDEAL_2021  DEFASAGEM_2021  FASE_2022 TURMA_2022  \
# 0  Nível 3 (7o e 8o ano)            -1.0        NaN        NaN
# 1                    NaN             NaN        0.0          K
# 2  Nível 3 (7o e 8o ano)             0.0        NaN        NaN
# 3                    NaN             NaN        2.0          J
# 4  Nível 2 (5o e 6o ano)             0.0        2.0          L
#
#    ANO_INGRESSO_2022 BOLSISTA_2022  INDE_2022  CG_2022  CF_2022  CT_2022  \
# 0                NaN           NaN        NaN      NaN      NaN      NaN
# 1             2022.0           Não   7.675509    245.0     66.0      6.0
# 2                NaN           NaN        NaN      NaN      NaN      NaN
# 3             2022.0           Não   7.117065    451.0     69.0      3.0
# 4             2019.0           Não   7.232336    415.0     61.0     12.0
#
#   PEDRA_2022                                DESTAQUE_IEG_2022  \
# 0        NaN                                              NaN
# 1   Ametista  Destaque: A sua boa entrega das lições de casa.
# 2        NaN                                              NaN
# 3   Ametista  Destaque: A sua boa entrega das lições de casa.
# 4   Ametista  Destaque: A sua boa entrega das lições de casa.
#
#                                    DESTAQUE_IDA_2022  \
# 0                                                NaN
# 1    Destaque: As suas boas notas na Passos Mágicos.
# 2                                                NaN
# 3  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 4  Melhorar: Empenhar-se mais nas aulas e avaliaç...
#
#                                    DESTAQUE_IPV_2022  IAA_2022  IEG_2022  \
# 0                                                NaN       NaN       NaN
# 1  Destaque: A sua boa integração aos Princípios ...  10.00002  7.581705
# 2                                                NaN       NaN       NaN
# 3  Destaque: A sua boa integração aos Princípios ...  10.00002  8.071429
# 4  Destaque: A sua boa integração aos Princípios ...   6.41668  8.557505
#
#    IPS_2022  IDA_2022  NOTA_PORT_2022  NOTA_MAT_2022  NOTA_ING_2022  \
# 0       NaN       NaN             NaN            NaN            NaN
# 1       7.5  8.816667        8.200000       9.433333            NaN
# 2       NaN       NaN             NaN            NaN            NaN
# 3       7.5  5.083333        5.000000       5.166667            NaN
# 4       7.5  7.083333        6.666667       7.500000            NaN
#
#    QTD_AVAL_2022  IPP_2022           REC_AVA_1_2022         REC_AVA_2_2022  \
# 0            NaN       NaN                      NaN                    NaN
# 1            2.0  5.625000  Mantido na Fase + Bolsa  Mantido na Fase atual
# 2            NaN       NaN                      NaN                    NaN
# 3            3.0  6.250000        Promovido de Fase  Mantido na Fase atual
# 4            3.0  6.458333    Mantido na Fase atual      Promovido de Fase
#
#           REC_AVA_3_2022 REC_AVA_4_2022 INDICADO_BOLSA_2022 PONTO_VIRADA_2022  \
# 0                    NaN            NaN                 NaN               NaN
# 1                    NaN            NaN                 Sim               Não
# 2                    NaN            NaN                 NaN               NaN
# 3      Promovido de Fase            NaN                 Não               Não
# 4  Mantido na Fase atual            NaN                 Não               Não
#
#    IPV_2022  IAN_2022      NIVEL_IDEAL_2022
# 0       NaN       NaN                   NaN
# 1  7.916665       5.0  Fase 2 (5º e 6º ano)
# 2       NaN       NaN                   NaN
# 3  8.055553       5.0  Fase 3 (7º e 8º ano)
# 4  7.833337       5.0  Fase 3 (7º e 8º ano)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1349 entries, 0 to 1348
# Data columns (total 69 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   INSTITUICAO_ENSINO_ALUNO_2020  728 non-null    object
#  1   NOME                           1349 non-null   object
#  2   IDADE_ALUNO_2020               728 non-null    object
#  3   ANOS_PM_2020                   728 non-null    object
#  4   FASE_TURMA_2020                728 non-null    object
#  5   PONTO_VIRADA_2020              702 non-null    object
#  6   INDE_2020                      728 non-null    object
#  7   INDE_CONCEITO_2020             728 non-null    object
#  8   PEDRA_2020                     728 non-null    object
#  9   DESTAQUE_IEG_2020              728 non-null    object
#  10  DESTAQUE_IDA_2020              728 non-null    object
#  11  DESTAQUE_IPV_2020              703 non-null    object
#  12  IAA_2020                       728 non-null    object
#  13  IEG_2020                       728 non-null    object
#  14  IPS_2020                       728 non-null    object
#  15  IDA_2020                       728 non-null    object
#  16  IPP_2020                       728 non-null    object
#  17  IPV_2020                       728 non-null    object
#  18  IAN_2020                       728 non-null    object
#  19  FASE_2021                      686 non-null    float64
#  20  TURMA_2021                     686 non-null    object
#  21  INSTITUICAO_ENSINO_ALUNO_2021  686 non-null    object
#  22  SINALIZADOR_INGRESSANTE_2021   686 non-null    object
#  23  PEDRA_2021                     686 non-null    object
#  24  INDE_2021                      686 non-null    object
#  25  IAA_2021                       686 non-null    float64
#  26  IEG_2021                       686 non-null    float64
#  27  IPS_2021                       686 non-null    float64
#  28  IDA_2021                       686 non-null    float64
#  29  IPP_2021                       686 non-null    float64
#  30  REC_EQUIPE_1_2021              686 non-null    object
#  31  REC_EQUIPE_2_2021              686 non-null    object
#  32  REC_EQUIPE_3_2021              686 non-null    object
#  33  REC_EQUIPE_4_2021              686 non-null    object
#  34  PONTO_VIRADA_2021              686 non-null    object
#  35  IPV_2021                       686 non-null    float64
#  36  IAN_2021                       686 non-null    float64
#  37  NIVEL_IDEAL_2021               686 non-null    object
#  38  DEFASAGEM_2021                 686 non-null    float64
#  39  FASE_2022                      862 non-null    float64
#  40  TURMA_2022                     862 non-null    object
#  41  ANO_INGRESSO_2022              862 non-null    float64
#  42  BOLSISTA_2022                  862 non-null    object
#  43  INDE_2022                      862 non-null    float64
#  44  CG_2022                        862 non-null    float64
#  45  CF_2022                        862 non-null    float64
#  46  CT_2022                        862 non-null    float64
#  47  PEDRA_2022                     862 non-null    object
#  48  DESTAQUE_IEG_2022              862 non-null    object
#  49  DESTAQUE_IDA_2022              862 non-null    object
#  50  DESTAQUE_IPV_2022              862 non-null    object
#  51  IAA_2022                       862 non-null    float64
#  52  IEG_2022                       862 non-null    float64
#  53  IPS_2022                       862 non-null    float64
#  54  IDA_2022                       862 non-null    float64
#  55  NOTA_PORT_2022                 860 non-null    float64
#  56  NOTA_MAT_2022                  860 non-null    float64
#  57  NOTA_ING_2022                  285 non-null    float64
#  58  QTD_AVAL_2022                  862 non-null    float64
#  59  IPP_2022                       862 non-null    float64
#  60  REC_AVA_1_2022                 862 non-null    object
#  61  REC_AVA_2_2022                 862 non-null    object
#  62  REC_AVA_3_2022                 626 non-null    object
#  63  REC_AVA_4_2022                 285 non-null    object
#  64  INDICADO_BOLSA_2022            862 non-null    object
#  65  PONTO_VIRADA_2022              862 non-null    object
#  66  IPV_2022                       862 non-null    float64
#  67  IAN_2022                       862 non-null    float64
#  68  NIVEL_IDEAL_2022               862 non-null    object
# dtypes: float64(26), object(43)
# memory usage: 727.3+ KB

# %%
df['PONTO_VIRADA_2021'].value_counts()
# Out:
# PONTO_VIRADA_2021
# Não       576
# Sim       108
# #NULO!      2
# Name: count, dtype: int64

# %% [markdown]
# # Tivemos adição de colunas novas no dataset ao longo do tempo 🤔

# %%
len(df.columns[df.columns.str.contains('2020')])
# Out:
# 18

# %%
df.columns[df.columns.str.contains('2020')]
# Out:
# Index(['INSTITUICAO_ENSINO_ALUNO_2020', 'IDADE_ALUNO_2020', 'ANOS_PM_2020',
#        'FASE_TURMA_2020', 'PONTO_VIRADA_2020', 'INDE_2020',
#        'INDE_CONCEITO_2020', 'PEDRA_2020', 'DESTAQUE_IEG_2020',
#        'DESTAQUE_IDA_2020', 'DESTAQUE_IPV_2020', 'IAA_2020', 'IEG_2020',
#        'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020'],
#       dtype='object')

# %%
len(df.columns[df.columns.str.contains('2021')])
# Out:
# 20

# %%
df.columns[df.columns.str.contains('2021')]
# Out:
# Index(['FASE_2021', 'TURMA_2021', 'INSTITUICAO_ENSINO_ALUNO_2021',
#        'SINALIZADOR_INGRESSANTE_2021', 'PEDRA_2021', 'INDE_2021', 'IAA_2021',
#        'IEG_2021', 'IPS_2021', 'IDA_2021', 'IPP_2021', 'REC_EQUIPE_1_2021',
#        'REC_EQUIPE_2_2021', 'REC_EQUIPE_3_2021', 'REC_EQUIPE_4_2021',
#        'PONTO_VIRADA_2021', 'IPV_2021', 'IAN_2021', 'NIVEL_IDEAL_2021',
#        'DEFASAGEM_2021'],
#       dtype='object')

# %%
len(df.columns[df.columns.str.contains('2022')])
# Out:
# 30

# %%
df.columns[df.columns.str.contains('2022')]
# Out:
# Index(['FASE_2022', 'TURMA_2022', 'ANO_INGRESSO_2022', 'BOLSISTA_2022',
#        'INDE_2022', 'CG_2022', 'CF_2022', 'CT_2022', 'PEDRA_2022',
#        'DESTAQUE_IEG_2022', 'DESTAQUE_IDA_2022', 'DESTAQUE_IPV_2022',
#        'IAA_2022', 'IEG_2022', 'IPS_2022', 'IDA_2022', 'NOTA_PORT_2022',
#        'NOTA_MAT_2022', 'NOTA_ING_2022', 'QTD_AVAL_2022', 'IPP_2022',
#        'REC_AVA_1_2022', 'REC_AVA_2_2022', 'REC_AVA_3_2022', 'REC_AVA_4_2022',
#        'INDICADO_BOLSA_2022', 'PONTO_VIRADA_2022', 'IPV_2022', 'IAN_2022',
#        'NIVEL_IDEAL_2022'],
#       dtype='object')

# %% [markdown]
# # Funções reutilizáveis 🤓

# %%
def filter_columns(df, filters: list): # adiciono no array o padrão que existe nas colunas e que não quero que tenha na saída final
    selected_columns = [True] * len(df.columns)  # Inicializa todas as colunas como True
    for index, column in enumerate(df.columns):
        if any(filter in column for filter in filters): selected_columns[index] = False
    return df[df.columns[selected_columns]]

# %%
def cleaning_dataset(df):
  _df = df.dropna(subset=df.columns.difference(['NOME']), how='all') # executa o dropna para todas as colunas sem visualizar a coluna NOME
  _df = _df[~_df.isna().all(axis=1)] # remove linhas com apenas NaN, se tiver algum dado na linha não remove
  return _df

# %%
def plot_exact_counter(size, x, y, df) -> None:
  import matplotlib.pyplot as plt
  import seaborn as sns
  import pandas as pd

  plt.figure(figsize=size)
  barplot = plt.bar(y.index, y.values)
  plt.xlabel(x)
  plt.ylabel('Count')

  for index, value in enumerate(y.values):
        plt.text(index, value, round(value, 2), color='black', ha="center")

  plt.show()

# %%
def plot_bar(df, col, titulo, xaxis, yaxis='Qty'):
  grupos = df[col].value_counts()

  fig = go.Figure(
      go.Bar(
          x=grupos.index,
          y=grupos,
          text=grupos,
          textposition='auto'
      )
  )

  fig.update_layout(
      title=titulo,
      xaxis=dict(tickmode='linear'),
      xaxis_title=xaxis,
      yaxis_title=yaxis,
  )

  fig.show()
  
def plot_histograma(df, col, titulo, rug=True):
  # faz o cálculo do KDE com o scipy
  data = df[col].values
  kde = gaussian_kde(data)
  x_vals = np.linspace(min(data), max(data), 1000)
  kde_vals = kde(x_vals)

  # faz o cálculo da quantidade ótima de bins (assim evitamos agrupamentos desnecessários)
  bins = len(np.histogram_bin_edges(data, bins='auto'))

  # cria os plots separados (histograma + kde + rug)
  # 1. histograma
  histogram = go.Histogram(x=data, nbinsx=bins, histnorm='probability density', name=f'Density: {col}')

  # 2. kde
  kde_line = go.Scatter(x=x_vals, y=kde_vals, mode='lines', name='Curve (KDE)', line=dict(color='red'))

  # 3. rug, mas apenas se ele tiver sido requisitado
  if rug:
    rug_plot = go.Scatter(
        x=data,
        y=[-0.01] * len(data),
        mode='markers',
        name='Obs',
        marker=dict(color='black', symbol='line-ns-open', size=10)
    )

  # figura principal
  fig = go.Figure()
  fig.add_trace(histogram)
  fig.add_trace(kde_line)
  fig.update_traces(texttemplate='%{y:.2%}', textposition='outside', selector=dict(type='histogram'))

  # configs
  fig.update_layout(
      title=titulo,
      xaxis_title='Value',
      yaxis_title='Frequency',
      yaxis=dict(range=[0, max(kde_vals) + 0.1]),
      bargap=0.015,
      uniformtext_mode='hide'
  )

  # configs com rug
  if rug:
    fig.add_trace(rug_plot)
    fig.update_layout(yaxis=dict(range=[-0.02, max(kde_vals) + 0.1]))
  # configs sem rug
  else:
    fig.update_layout(xaxis=dict(tickmode='linear'))

  fig.show()
  

def plot_boxplot(df, col, titulo):
  fig = px.box(y=df[col], points="all", title=titulo)

  fig.update_layout(
      yaxis_title='Valor'
  )

  fig.update_yaxes(dtick=1)

  fig.show()
     


def plot_boxplot_comparativo(df, col):
  fig = px.box(data_frame=df, x='ANO', y=col, points="all", title=f'Distribuição do {col} comparativa', color='ANO')

  fig.update_layout(
      yaxis_title='Valor'
  )

  fig.update_yaxes(dtick=1)

  fig.show()

# %%
def analyse_corr(df):
  import seaborn as sns
  import matplotlib.pyplot as plt

  df = df.apply(pd.to_numeric, errors='coerce')

  corr_matrix = df.corr()
  plt.figure(figsize=(10, 8))
  sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
  plt.show()

# %% [markdown]
# # DF - 2020

# %%
df_2020 = filter_columns(df, ['2021', '2022'])
df_2020.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 0                Escola Pública  ALUNO-1               11            2
# 1                           NaN  ALUNO-2              NaN          NaN
# 2                Escola Pública  ALUNO-3               12            2
# 3                Escola Pública  ALUNO-4               10            2
# 4                Escola Pública  ALUNO-5               10            1
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020          INDE_2020 INDE_CONCEITO_2020  \
# 0              2H               Não           7.883752                  B
# 1             NaN               NaN                NaN                NaN
# 2              3H               Não  7.856389666666666                  B
# 3              1D               Não           5.076252                  D
# 4              2M               Não           8.077085                  B
#
#   PEDRA_2020                                  DESTAQUE_IEG_2020  \
# 0   Ametista  Seu destaque em 2020: A sua boa entrega das li...
# 1        NaN                                                NaN
# 2   Ametista  Seu destaque em 2020: A sua boa entrega das li...
# 3    Quartzo  Ponto a melhorar em 2021: Melhorar a sua entre...
# 4   Ametista  Seu destaque em 2020: A sua boa entrega das li...
#
#                                    DESTAQUE_IDA_2020  \
# 0  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 1                                                NaN
# 2  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 3  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 4  Seu destaque em 2020: As suas boas notas na Pa...
#
#                                    DESTAQUE_IPV_2020           IAA_2020  \
# 0  Seu destaque em 2020: A sua boa integração aos...  8.500020000000001
# 1                                                NaN                NaN
# 2  Seu destaque em 2020: A sua boa integração aos...            7.91667
# 3  Ponto a melhorar em 2021: Integrar-se mais aos...  8.000020000000001
# 4  Seu destaque em 2020: A sua boa integração aos...            7.50002
#
#   IEG_2020 IPS_2020 IDA_2020 IPP_2020           IPV_2020 IAN_2020
# 0      8.7      7.5        7   5.9375               7.75       10
# 1      NaN      NaN      NaN      NaN                NaN      NaN
# 2      8.9      7.5      5.5    8.125  8.111113333333334       10
# 3      4.1    6.875        0   7.1875               7.75        5
# 4        8      7.5      7.5   8.4375           8.166665       10

# %%
len(df_2020) # com NaN
# Out:
# 1349

# %%
df_2020.infer_objects().dtypes
# Out:
# INSTITUICAO_ENSINO_ALUNO_2020    object
# NOME                             object
# IDADE_ALUNO_2020                 object
# ANOS_PM_2020                     object
# FASE_TURMA_2020                  object
# PONTO_VIRADA_2020                object
# INDE_2020                        object
# INDE_CONCEITO_2020               object
# PEDRA_2020                       object
# DESTAQUE_IEG_2020                object
# DESTAQUE_IDA_2020                object
# DESTAQUE_IPV_2020                object
# IAA_2020                         object
# IEG_2020                         object
# IPS_2020                         object
# IDA_2020                         object
# IPP_2020                         object
# IPV_2020                         object
# IAN_2020                         object
# dtype: object

# %%
df_2020[['IDADE_ALUNO_2020','ANOS_PM_2020', 'INDE_2020', 'IAA_2020', 'IEG_2020', 'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020']]=df_2020[['IDADE_ALUNO_2020','ANOS_PM_2020', 'INDE_2020', 'IAA_2020', 'IEG_2020', 'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020']].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "D108"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 df_2020[['IDADE_ALUNO_2020','ANOS_PM_2020', 'INDE_2020', 'IAA_2020', 'IEG_2020', 'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020']]=df_2020[['IDADE_ALUNO_2020','ANOS_PM_2020', 'INDE_2020', 'IAA_2020', 'IEG_2020', 'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020']].apply(pd.to_numeric)
#
# File ~/pess/Pós/.venv/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/pess/Pós/.venv/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/pess/Pós/.venv/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/pess/Pós/.venv/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File ~/pess/Pós/.venv/lib/python3.12/site-packages/pandas/core/tools/numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
#     235         coerce_numeric=coerce_numeric,
#     236         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     237         or isinstance(values_dtype, StringDtype)
#     238         and not values_dtype.storage == "pyarrow_numpy",
#     239     )
#     240 except (ValueError, TypeError):
#     241     if errors == "raise":
#
# File lib.pyx:2433, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "D108" at position 1258

# %%
df_2020.iloc[1258]
# Out:
# INSTITUICAO_ENSINO_ALUNO_2020          V202
# NOME                             ALUNO-1259
# IDADE_ALUNO_2020                       D108
# ANOS_PM_2020                           D971
# FASE_TURMA_2020                        D207
# PONTO_VIRADA_2020                     D9600
# INDE_2020                              D980
# INDE_CONCEITO_2020                  D9891/2
# PEDRA_2020                         D9891/2A
# DESTAQUE_IEG_2020                      D301
# DESTAQUE_IDA_2020                      D302
# DESTAQUE_IPV_2020                       NaN
# IAA_2020                               D910
# IEG_2020                               V920
# IPS_2020                               D930
# IDA_2020                               D940
# IPP_2020                               D950
# IPV_2020                               D960
# IAN_2020                               D970
# Name: 1258, dtype: object

# %%
df_2020.drop(index=1258,axis=1,inplace=True)
# Out:
# /var/folders/v0/84lzkbf93gq9sjdc9ccj38p00000gq/T/ipykernel_52545/3870966097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020.drop(index=1258,axis=1,inplace=True)

# %%
df_2020[['IDADE_ALUNO_2020','ANOS_PM_2020', 'INDE_2020', 'IAA_2020', 'IEG_2020', 'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020']]=df_2020[['IDADE_ALUNO_2020','ANOS_PM_2020', 'INDE_2020', 'IAA_2020', 'IEG_2020', 'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020']].apply(pd.to_numeric)
# Out:
# /var/folders/v0/84lzkbf93gq9sjdc9ccj38p00000gq/T/ipykernel_52545/2901701478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020[['IDADE_ALUNO_2020','ANOS_PM_2020', 'INDE_2020', 'IAA_2020', 'IEG_2020', 'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020']]=df_2020[['IDADE_ALUNO_2020','ANOS_PM_2020', 'INDE_2020', 'IAA_2020', 'IEG_2020', 'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020']].apply(pd.to_numeric)

# %%
df_2020 = cleaning_dataset(df_2020)
len(df_2020)
# Out:
# 727

# %%
df_2020['INSTITUICAO_ENSINO_ALUNO_2020'].value_counts()
# Out:
# INSTITUICAO_ENSINO_ALUNO_2020
# Escola Pública          598
# Rede Decisão/União      101
# FIAP                     11
# UNISA                    10
# Estácio                   3
# Einstein                  2
# Escola João Paulo II      2
# Name: count, dtype: int64

# %%
df_2020.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME  IDADE_ALUNO_2020  ANOS_PM_2020  \
# 0                Escola Pública  ALUNO-1              11.0           2.0
# 2                Escola Pública  ALUNO-3              12.0           2.0
# 3                Escola Pública  ALUNO-4              10.0           2.0
# 4                Escola Pública  ALUNO-5              10.0           1.0
# 7            Rede Decisão/União  ALUNO-8              14.0           3.0
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020  INDE_2020 INDE_CONCEITO_2020 PEDRA_2020  \
# 0              2H               Não   7.883752                  B   Ametista
# 2              3H               Não   7.856390                  B   Ametista
# 3              1D               Não   5.076252                  D    Quartzo
# 4              2M               Não   8.077085                  B   Ametista
# 7              4L               Sim   8.381391                  B   Ametista
#
#                                    DESTAQUE_IEG_2020  \
# 0  Seu destaque em 2020: A sua boa entrega das li...
# 2  Seu destaque em 2020: A sua boa entrega das li...
# 3  Ponto a melhorar em 2021: Melhorar a sua entre...
# 4  Seu destaque em 2020: A sua boa entrega das li...
# 7  Seu destaque em 2020: A sua boa entrega das li...
#
#                                    DESTAQUE_IDA_2020  \
# 0  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 2  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 3  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 4  Seu destaque em 2020: As suas boas notas na Pa...
# 7  Ponto a melhorar em 2021: Empenhar-se mais nas...
#
#                                    DESTAQUE_IPV_2020  IAA_2020  IEG_2020  \
# 0  Seu destaque em 2020: A sua boa integração aos...   8.50002       8.7
# 2  Seu destaque em 2020: A sua boa integração aos...   7.91667       8.9
# 3  Ponto a melhorar em 2021: Integrar-se mais aos...   8.00002       4.1
# 4  Seu destaque em 2020: A sua boa integração aos...   7.50002       8.0
# 7  Seu destaque em 2020: A sua boa integração aos...   8.33334       9.9
#
#    IPS_2020  IDA_2020  IPP_2020  IPV_2020  IAN_2020
# 0     7.500  7.000000    5.9375  7.750000      10.0
# 2     7.500  5.500000    8.1250  8.111113      10.0
# 3     6.875  0.000000    7.1875  7.750000       5.0
# 4     7.500  7.500000    8.4375  8.166665      10.0
# 7     4.375  7.333333    8.7500  8.944450      10.0

# %%
df_2020['PEDRA_2020'].value_counts()
# Out:
# PEDRA_2020
# Ametista    336
# Ágata       171
# Quartzo     128
# Topázio      92
# Name: count, dtype: int64

# %%
plot_exact_counter(size=(10, 6), x='PEDRA_2020', y=df_2020['PEDRA_2020'].value_counts(), df=df_2020)

# %%
analyse_corr(df_2020)

# %% [markdown]
# # **Ideias** 🤔
#
# * Predição de desempenho futuro e análise de outliers (*O que fez alguns alunos serem um dos melhores que já passou na Passos?*)
# * Predição para recomendação de bolsas, intercambio, etc
# * Análise comparatória de 2020, 2021 e 2022
# * Análise de alunos (*de forma individual? 🤔*) ao longo dos anos (*Ex: temos dados do 'ALUNO 1' em 2020 e 2021, já em 2022 não temos dados... Seria talvez desistência?*)
# * Análise de alunos que estão indo bem Vs alunos que não estão indo bem. Tentar entender o porquê um aluno vai bem e outro não.
# * Tentar prever qual seria a “pedra” de um novo aluno com X pontuações de índices em uma nova entrada

# %% [markdown]
# # 2021

# %%
df_2021 = filter_columns(df, ['2020', '2022'])
df_2021 = cleaning_dataset(df_2021)
df_2021.head()
# Out:
#         NOME  FASE_2021 TURMA_2021 INSTITUICAO_ENSINO_ALUNO_2021  \
# 0    ALUNO-1        2.0          G                  Rede Decisão
# 2    ALUNO-3        3.0          F                Escola Pública
# 4    ALUNO-5        2.0          L                Escola Pública
# 7    ALUNO-8        5.0          L                  Rede Decisão
# 10  ALUNO-11        1.0          A                  Rede Decisão
#
#    SINALIZADOR_INGRESSANTE_2021 PEDRA_2021 INDE_2021  IAA_2021  IEG_2021  \
# 0                   Ingressante   Ametista     7.319       7.5       6.3
# 2                      Veterano   Ametista     7.021       7.1       6.9
# 4                      Veterano   Ametista     7.399       7.4       7.5
# 7                      Veterano    Topázio     8.269       8.8       8.6
# 10                     Veterano    Topázio     8.990       9.0      10.0
#
#     IPS_2021  IDA_2021  IPP_2021          REC_EQUIPE_1_2021  \
# 0        6.9       8.8       7.7          Promovido de Fase
# 2        6.3       5.6       7.3          Promovido de Fase
# 4        7.5       5.4       8.5          Promovido de Fase
# 7        7.5       7.1       8.0  Promovido de Fase + Bolsa
# 10       6.3       8.8       7.7          Promovido de Fase
#
#         REC_EQUIPE_2_2021      REC_EQUIPE_3_2021      REC_EQUIPE_4_2021  \
# 0       Promovido de Fase  Mantido na Fase atual           Não avaliado
# 2       Promovido de Fase  Mantido na Fase atual           Não avaliado
# 4   Mantido na Fase atual  Mantido na Fase atual           Não avaliado
# 7       Promovido de Fase      Promovido de Fase  Mantido na Fase atual
# 10  Mantido na Fase atual  Mantido na Fase atual           Não avaliado
#
#    PONTO_VIRADA_2021  IPV_2021  IAN_2021       NIVEL_IDEAL_2021  \
# 0                Não       8.1       5.0  Nível 3 (7o e 8o ano)
# 2                Não       7.2      10.0  Nível 3 (7o e 8o ano)
# 4                Não       7.4      10.0  Nível 2 (5o e 6o ano)
# 7                Não       8.5      10.0        Nível 5 (1o EM)
# 10               Sim       9.7      10.0       Nível 1 (4o ano)
#
#     DEFASAGEM_2021
# 0             -1.0
# 2              0.0
# 4              0.0
# 7              0.0
# 10             0.0

# %%
df_2021[['FASE_2021','INDE_2021', 'IAA_2021', 'IEG_2021', 'IPS_2021', 'IDA_2021', 'IPP_2021', 'IPV_2021', 'IAN_2021','DEFASAGEM_2021']].apply(pd.to_numeric).dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "#NULO!"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df_2021[['FASE_2021','INDE_2021', 'IAA_2021', 'IEG_2021', 'IPS_2021', 'IDA_2021', 'IPP_2021', 'IPV_2021', 'IAN_2021','DEFASAGEM_2021']].apply(pd.to_numeric).dtypes
#
# File ~/pess/Pós/.venv/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/pess/Pós/.venv/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/pess/Pós/.venv/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/pess/Pós/.venv/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File ~/pess/Pós/.venv/lib/python3.12/site-packages/pandas/core/tools/numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
#     235         coerce_numeric=coerce_numeric,
#     236         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     237         or isinstance(values_dtype, StringDtype)
#     238         and not values_dtype.storage == "pyarrow_numpy",
#     239     )
#     240 except (ValueError, TypeError):
#     241     if errors == "raise":
#
# File lib.pyx:2433, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "#NULO!" at position 32

# %%
df_2021 = df_2021.replace('#NULO!', np.nan)
display(len(df_2021))
df_2021.iloc[32]
# Out:
# 686
# NOME                                          ALUNO-71
# FASE_2021                                          0.0
# TURMA_2021                                           J
# INSTITUICAO_ENSINO_ALUNO_2021           Escola Pública
# SINALIZADOR_INGRESSANTE_2021                  Veterano
# PEDRA_2021                                         NaN
# INDE_2021                                          NaN
# IAA_2021                                           7.4
# IEG_2021                                           0.0
# IPS_2021                                           5.0
# IDA_2021                                           3.6
# IPP_2021                                           0.0
# REC_EQUIPE_1_2021                         Não avaliado
# REC_EQUIPE_2_2021                         Não avaliado
# REC_EQUIPE_3_2021                         Não avaliado
# REC_EQUIPE_4_2021                         Não avaliado
# PONTO_VIRADA_2021                                  NaN
# IPV_2021                                           0.0
# IAN_2021                                           5.0
# NIVEL_IDEAL_2021                 Nível 2 (5o e 6o ano)
# DEFASAGEM_2021                                    -2.0
# Name: 70, dtype: object

# %%
df_2021 = cleaning_dataset(df_2021)
len(df_2021)
# Out:
# 686

# %%
df_2021[['FASE_2021','INDE_2021', 'IAA_2021', 'IEG_2021', 'IPS_2021', 'IDA_2021', 'IPP_2021', 'IPV_2021', 'IAN_2021','DEFASAGEM_2021']]=df_2021[['FASE_2021','INDE_2021', 'IAA_2021', 'IEG_2021', 'IPS_2021', 'IDA_2021', 'IPP_2021', 'IPV_2021', 'IAN_2021','DEFASAGEM_2021']].apply(pd.to_numeric)

# %%
df_2021['INSTITUICAO_ENSINO_ALUNO_2021'].value_counts()
# Out:
# INSTITUICAO_ENSINO_ALUNO_2021
# Escola Pública    557
# Rede Decisão      127
# Escola JP II        2
# Name: count, dtype: int64

# %%
df_2021['PEDRA_2021'].value_counts()
# Out:
# PEDRA_2021
# Ametista    295
# Ágata       178
# Quartzo     110
# Topázio     101
# Name: count, dtype: int64

# %%
plot_exact_counter(size=(10, 6), x='PEDRA_2021', y=df_2021['PEDRA_2021'].value_counts(), df=df_2021)

# %%
analyse_corr(df_2021)

# %% [markdown]
# # 2022

# %%
df_2022 = filter_columns(df, ['2020', '2021'])
df_2022 = cleaning_dataset(df_2022)
df_2022.head()
# Out:
#       NOME  FASE_2022 TURMA_2022  ANO_INGRESSO_2022 BOLSISTA_2022  INDE_2022  \
# 1  ALUNO-2        0.0          K             2022.0           Não   7.675509
# 3  ALUNO-4        2.0          J             2022.0           Não   7.117065
# 4  ALUNO-5        2.0          L             2019.0           Não   7.232336
# 5  ALUNO-6        2.0          K             2022.0           Não   7.741669
# 6  ALUNO-7        1.0          U             2022.0           Não   7.406743
#
#    CG_2022  CF_2022  CT_2022 PEDRA_2022  \
# 1    245.0     66.0      6.0   Ametista
# 3    451.0     69.0      3.0   Ametista
# 4    415.0     61.0     12.0   Ametista
# 5    221.0     35.0      2.0   Ametista
# 6    357.0     93.0      7.0   Ametista
#
#                                  DESTAQUE_IEG_2022  \
# 1  Destaque: A sua boa entrega das lições de casa.
# 3  Destaque: A sua boa entrega das lições de casa.
# 4  Destaque: A sua boa entrega das lições de casa.
# 5  Destaque: A sua boa entrega das lições de casa.
# 6  Destaque: A sua boa entrega das lições de casa.
#
#                                    DESTAQUE_IDA_2022  \
# 1    Destaque: As suas boas notas na Passos Mágicos.
# 3  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 4  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 5  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 6  Melhorar: Empenhar-se mais nas aulas e avaliaç...
#
#                                    DESTAQUE_IPV_2022  IAA_2022  IEG_2022  \
# 1  Destaque: A sua boa integração aos Princípios ...  10.00002  7.581705
# 3  Destaque: A sua boa integração aos Princípios ...  10.00002  8.071429
# 4  Destaque: A sua boa integração aos Princípios ...   6.41668  8.557505
# 5  Destaque: A sua boa integração aos Princípios ...   9.00002  9.333333
# 6  Destaque: A sua boa integração aos Princípios ...  10.00002  9.314954
#
#    IPS_2022  IDA_2022  NOTA_PORT_2022  NOTA_MAT_2022  NOTA_ING_2022  \
# 1       7.5  8.816667        8.200000       9.433333            NaN
# 3       7.5  5.083333        5.000000       5.166667            NaN
# 4       7.5  7.083333        6.666667       7.500000            NaN
# 5       7.5  5.500000        3.000000       8.000000            NaN
# 6       7.5  5.583333        4.666667       6.500000            NaN
#
#    QTD_AVAL_2022  IPP_2022           REC_AVA_1_2022         REC_AVA_2_2022  \
# 1            2.0  5.625000  Mantido na Fase + Bolsa  Mantido na Fase atual
# 3            3.0  6.250000        Promovido de Fase  Mantido na Fase atual
# 4            3.0  6.458333    Mantido na Fase atual      Promovido de Fase
# 5            3.0  6.250000    Mantido na Fase atual      Promovido de Fase
# 6            2.0  5.937500        Promovido de Fase      Promovido de Fase
#
#           REC_AVA_3_2022 REC_AVA_4_2022 INDICADO_BOLSA_2022 PONTO_VIRADA_2022  \
# 1                    NaN            NaN                 Sim               Não
# 3      Promovido de Fase            NaN                 Não               Não
# 4  Mantido na Fase atual            NaN                 Não               Não
# 5  Mantido na Fase atual            NaN                 Não               Não
# 6                    NaN            NaN                 Não               Não
#
#    IPV_2022  IAN_2022      NIVEL_IDEAL_2022
# 1  7.916665       5.0  Fase 2 (5º e 6º ano)
# 3  8.055553       5.0  Fase 3 (7º e 8º ano)
# 4  7.833337       5.0  Fase 3 (7º e 8º ano)
# 5  7.500000      10.0  Fase 2 (5º e 6º ano)
# 6  7.916670       5.0  Fase 2 (5º e 6º ano)

# %%
df_2022[['FASE_2022','ANO_INGRESSO_2022','INDE_2022','CG_2022','CF_2022','CT_2022','IAA_2022','IEG_2022','IPS_2022','IDA_2022','IPP_2022','IPV_2022','IAN_2022','NOTA_PORT_2022','NOTA_MAT_2022','NOTA_ING_2022','QTD_AVAL_2022']]=df_2022[['FASE_2022','ANO_INGRESSO_2022','INDE_2022','CG_2022','CF_2022','CT_2022','IAA_2022','IEG_2022','IPS_2022','IDA_2022','IPP_2022','IPV_2022','IAN_2022','NOTA_PORT_2022','NOTA_MAT_2022','NOTA_ING_2022','QTD_AVAL_2022']].apply(pd.to_numeric)

# %%
df_2022['PEDRA_2022'].value_counts()
# Out:
# PEDRA_2022
# Ametista    348
# Ágata       250
# Quartzo     134
# Topázio     130
# Name: count, dtype: int64

# %%
plot_exact_counter(size=(10, 6), x='PEDRA_2022', y=df_2022['PEDRA_2022'].value_counts(), df=df_2022)

# %%
analyse_corr(df_2022)

# %%
plot_bar(df_2020, 'INSTITUICAO_ENSINO_ALUNO_2020', 'Education Institutions in 2020', xaxis='Education Ins.')

# %%
plot_bar(df_2021, 'INSTITUICAO_ENSINO_ALUNO_2021', 'Education Institutions in 2021', xaxis='Education Ins.')

# %%
plot_histograma(df_2020, 'INDE_2020', 2020)
plot_histograma(df_2021.dropna(), 'INDE_2021', 2021)
plot_histograma(df_2022, 'INDE_2022', 2022)

# %% [markdown]
# ## Análise Comparativa de 2020, 2021 e 2022

# %%
import pandas as pd

def padronizar_colunas(df, ano):
    """ Remove o sufixo do ano nas colunas e adiciona a coluna 'Ano' """
    df = df.copy()
    df.columns = [col.replace(f"_{ano}", "") for col in df.columns]  # Remover o sufixo do ano
    df["Ano"] = ano  # Adicionar a coluna Ano
    return df

# Aplicar a função nos três DataFrames
df_2020_clean = padronizar_colunas(df_2020, 2020)
df_2021_clean = padronizar_colunas(df_2021, 2021)
df_2022_clean = padronizar_colunas(df_2022, 2022)

# Unir os três DataFrames em um único
df_merged = pd.concat([df_2020_clean, df_2021_clean, df_2022_clean], ignore_index=True)

# Exibir as primeiras linhas do novo DataFrame
df_merged.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO     NOME  IDADE_ALUNO  ANOS_PM FASE_TURMA  \
# 0           Escola Pública  ALUNO-1         11.0      2.0         2H
# 1           Escola Pública  ALUNO-3         12.0      2.0         3H
# 2           Escola Pública  ALUNO-4         10.0      2.0         1D
# 3           Escola Pública  ALUNO-5         10.0      1.0         2M
# 4       Rede Decisão/União  ALUNO-8         14.0      3.0         4L
#
#   PONTO_VIRADA      INDE INDE_CONCEITO     PEDRA  \
# 0          Não  7.883752             B  Ametista
# 1          Não  7.856390             B  Ametista
# 2          Não  5.076252             D   Quartzo
# 3          Não  8.077085             B  Ametista
# 4          Sim  8.381391             B  Ametista
#
#                                         DESTAQUE_IEG  \
# 0  Seu destaque em 2020: A sua boa entrega das li...
# 1  Seu destaque em 2020: A sua boa entrega das li...
# 2  Ponto a melhorar em 2021: Melhorar a sua entre...
# 3  Seu destaque em 2020: A sua boa entrega das li...
# 4  Seu destaque em 2020: A sua boa entrega das li...
#
#                                         DESTAQUE_IDA  \
# 0  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 1  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 2  Ponto a melhorar em 2021: Empenhar-se mais nas...
# 3  Seu destaque em 2020: As suas boas notas na Pa...
# 4  Ponto a melhorar em 2021: Empenhar-se mais nas...
#
#                                         DESTAQUE_IPV      IAA  IEG    IPS  \
# 0  Seu destaque em 2020: A sua boa integração aos...  8.50002  8.7  7.500
# 1  Seu destaque em 2020: A sua boa integração aos...  7.91667  8.9  7.500
# 2  Ponto a melhorar em 2021: Integrar-se mais aos...  8.00002  4.1  6.875
# 3  Seu destaque em 2020: A sua boa integração aos...  7.50002  8.0  7.500
# 4  Seu destaque em 2020: A sua boa integração aos...  8.33334  9.9  4.375
#
#         IDA     IPP       IPV   IAN   Ano  FASE TURMA SINALIZADOR_INGRESSANTE  \
# 0  7.000000  5.9375  7.750000  10.0  2020   NaN   NaN                     NaN
# 1  5.500000  8.1250  8.111113  10.0  2020   NaN   NaN                     NaN
# 2  0.000000  7.1875  7.750000   5.0  2020   NaN   NaN                     NaN
# 3  7.500000  8.4375  8.166665  10.0  2020   NaN   NaN                     NaN
# 4  7.333333  8.7500  8.944450  10.0  2020   NaN   NaN                     NaN
#
#   REC_EQUIPE_1 REC_EQUIPE_2 REC_EQUIPE_3 REC_EQUIPE_4 NIVEL_IDEAL  DEFASAGEM  \
# 0          NaN          NaN          NaN          NaN         NaN        NaN
# 1          NaN          NaN          NaN          NaN         NaN        NaN
# 2          NaN          NaN          NaN          NaN         NaN        NaN
# 3          NaN          NaN          NaN          NaN         NaN        NaN
# 4          NaN          NaN          NaN          NaN         NaN        NaN
#
#    ANO_INGRESSO BOLSISTA  CG  CF  CT  NOTA_PORT  NOTA_MAT  NOTA_ING  QTD_AVAL  \
# 0           NaN      NaN NaN NaN NaN        NaN       NaN       NaN       NaN
# 1           NaN      NaN NaN NaN NaN        NaN       NaN       NaN       NaN
# 2           NaN      NaN NaN NaN NaN        NaN       NaN       NaN       NaN
# 3           NaN      NaN NaN NaN NaN        NaN       NaN       NaN       NaN
# 4           NaN      NaN NaN NaN NaN        NaN       NaN       NaN       NaN
#
#   REC_AVA_1 REC_AVA_2 REC_AVA_3 REC_AVA_4 INDICADO_BOLSA
# 0       NaN       NaN       NaN       NaN            NaN
# 1       NaN       NaN       NaN       NaN            NaN
# 2       NaN       NaN       NaN       NaN            NaN
# 3       NaN       NaN       NaN       NaN            NaN
# 4       NaN       NaN       NaN       NaN            NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Criar um novo DataFrame apenas com médias por ano
df_medias = pd.DataFrame({
    "Ano": ["2020", "2021", "2022"],
    "Média das Notas": [
        df_2020["INDE_2020"].mean(axis=0),
        df_2021["INDE_2021"].mean(),
        df_2022["INDE_2022"].mean()
    ]
})

# Plotando gráfico de evolução da média das notas
plt.figure(figsize=(8, 5))
sns.lineplot(data=df_medias, x="Ano", y="Média das Notas", marker="o")
plt.xlabel("Ano")
plt.ylabel("Média das Notas")
plt.title("Evolução da Média das Notas (2020-2022)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Análise de Alunos ao Longo dos Anos

# %%
df_merged
# Out:
#      INSTITUICAO_ENSINO_ALUNO        NOME  IDADE_ALUNO  ANOS_PM FASE_TURMA  \
# 0              Escola Pública     ALUNO-1         11.0      2.0         2H
# 1              Escola Pública     ALUNO-3         12.0      2.0         3H
# 2              Escola Pública     ALUNO-4         10.0      2.0         1D
# 3              Escola Pública     ALUNO-5         10.0      1.0         2M
# 4          Rede Decisão/União     ALUNO-8         14.0      3.0         4L
# ...                       ...         ...          ...      ...        ...
# 2270                      NaN  ALUNO-1342          NaN      NaN        NaN
# 2271                      NaN  ALUNO-1343          NaN      NaN        NaN
# 2272                      NaN  ALUNO-1346          NaN      NaN        NaN
# 2273                      NaN  ALUNO-1348          NaN      NaN        NaN
# 2274                      NaN  ALUNO-1349          NaN      NaN        NaN
#
#      PONTO_VIRADA      INDE INDE_CONCEITO     PEDRA  \
# 0             Não  7.883752             B  Ametista
# 1             Não  7.856390             B  Ametista
# 2             Não  5.076252             D   Quartzo
# 3             Não  8.077085             B  Ametista
# 4             Sim  8.381391             B  Ametista
# ...           ...       ...           ...       ...
# 2270          Não  8.150001           NaN   Topázio
# 2271          Não  5.674644           NaN   Quartzo
# 2272          Sim  8.135538           NaN   Topázio
# 2273          Não  6.749981           NaN     Ágata
# 2274          Não  6.399688           NaN     Ágata
#
#                                            DESTAQUE_IEG  \
# 0     Seu destaque em 2020: A sua boa entrega das li...
# 1     Seu destaque em 2020: A sua boa entrega das li...
# 2     Ponto a melhorar em 2021: Melhorar a sua entre...
# 3     Seu destaque em 2020: A sua boa entrega das li...
# 4     Seu destaque em 2020: A sua boa entrega das li...
# ...                                                 ...
# 2270    Destaque: A sua boa entrega das lições de casa.
# 2271  Melhorar: Melhorar a sua entrega de lições de ...
# 2272    Destaque: A sua boa entrega das lições de casa.
# 2273    Destaque: A sua boa entrega das lições de casa.
# 2274    Destaque: A sua boa entrega das lições de casa.
#
#                                            DESTAQUE_IDA  \
# 0     Ponto a melhorar em 2021: Empenhar-se mais nas...
# 1     Ponto a melhorar em 2021: Empenhar-se mais nas...
# 2     Ponto a melhorar em 2021: Empenhar-se mais nas...
# 3     Seu destaque em 2020: As suas boas notas na Pa...
# 4     Ponto a melhorar em 2021: Empenhar-se mais nas...
# ...                                                 ...
# 2270    Destaque: As suas boas notas na Passos Mágicos.
# 2271  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 2272    Destaque: As suas boas notas na Passos Mágicos.
# 2273  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 2274  Melhorar: Empenhar-se mais nas aulas e avaliaç...
#
#                                            DESTAQUE_IPV      IAA       IEG  \
# 0     Seu destaque em 2020: A sua boa integração aos...  8.50002  8.700000
# 1     Seu destaque em 2020: A sua boa integração aos...  7.91667  8.900000
# 2     Ponto a melhorar em 2021: Integrar-se mais aos...  8.00002  4.100000
# 3     Seu destaque em 2020: A sua boa integração aos...  7.50002  8.000000
# 4     Seu destaque em 2020: A sua boa integração aos...  8.33334  9.900000
# ...                                                 ...      ...       ...
# 2270  Destaque: A sua boa integração aos Princípios ...  7.91668  9.666667
# 2271  Melhorar: Integrar-se mais aos Princípios Pass...  7.41668  6.470435
# 2272  Destaque: A sua boa integração aos Princípios ...  9.00002  9.031839
# 2273  Melhorar: Integrar-se mais aos Princípios Pass...  8.33334  9.178030
# 2274  Melhorar: Integrar-se mais aos Princípios Pass...  7.91667  7.540114
#
#         IPS       IDA      IPP       IPV   IAN   Ano  FASE TURMA  \
# 0     7.500  7.000000  5.93750  7.750000  10.0  2020   NaN   NaN
# 1     7.500  5.500000  8.12500  8.111113  10.0  2020   NaN   NaN
# 2     6.875  0.000000  7.18750  7.750000   5.0  2020   NaN   NaN
# 3     7.500  7.500000  8.43750  8.166665  10.0  2020   NaN   NaN
# 4     4.375  7.333333  8.75000  8.944450  10.0  2020   NaN   NaN
# ...     ...       ...      ...       ...   ...   ...   ...   ...
# 2270  7.500  7.750000  6.25000  7.500000  10.0  2022   2.0     K
# 2271  6.250  2.000000  6.25000  7.444443   5.0  2022   2.0     K
# 2272  7.500  9.000000  5.62500  9.083340   5.0  2022   0.0     U
# 2273  5.625  5.900000  6.71875  5.833328   5.0  2022   4.0     P
# 2274  7.500  4.500000  7.50000  5.999993   5.0  2022   3.0     M
#
#      SINALIZADOR_INGRESSANTE REC_EQUIPE_1 REC_EQUIPE_2 REC_EQUIPE_3  \
# 0                        NaN          NaN          NaN          NaN
# 1                        NaN          NaN          NaN          NaN
# 2                        NaN          NaN          NaN          NaN
# 3                        NaN          NaN          NaN          NaN
# 4                        NaN          NaN          NaN          NaN
# ...                      ...          ...          ...          ...
# 2270                     NaN          NaN          NaN          NaN
# 2271                     NaN          NaN          NaN          NaN
# 2272                     NaN          NaN          NaN          NaN
# 2273                     NaN          NaN          NaN          NaN
# 2274                     NaN          NaN          NaN          NaN
#
#      REC_EQUIPE_4           NIVEL_IDEAL  DEFASAGEM  ANO_INGRESSO BOLSISTA  \
# 0             NaN                   NaN        NaN           NaN      NaN
# 1             NaN                   NaN        NaN           NaN      NaN
# 2             NaN                   NaN        NaN           NaN      NaN
# 3             NaN                   NaN        NaN           NaN      NaN
# 4             NaN                   NaN        NaN           NaN      NaN
# ...           ...                   ...        ...           ...      ...
# 2270          NaN  Fase 2 (5º e 6º ano)        NaN        2022.0      Não
# 2271          NaN       Fase 4 (9º ano)        NaN        2018.0      Não
# 2272          NaN       Fase 1 (4º ano)        NaN        2022.0      Não
# 2273          NaN        Fase 5 (1º EM)        NaN        2018.0      Sim
# 2274          NaN        Fase 5 (1º EM)        NaN        2022.0      Não
#
#          CG     CF    CT  NOTA_PORT  NOTA_MAT  NOTA_ING  QTD_AVAL  \
# 0       NaN    NaN   NaN        NaN       NaN       NaN       NaN
# 1       NaN    NaN   NaN        NaN       NaN       NaN       NaN
# 2       NaN    NaN   NaN        NaN       NaN       NaN       NaN
# 3       NaN    NaN   NaN        NaN       NaN       NaN       NaN
# 4       NaN    NaN   NaN        NaN       NaN       NaN       NaN
# ...     ...    ...   ...        ...       ...       ...       ...
# 2270   99.0   13.0   1.0   6.000000  9.500000       NaN       3.0
# 2271  763.0  141.0  11.0   2.000000  2.000000       NaN       3.0
# 2272  105.0   30.0   2.0   9.166667  8.833333       NaN       2.0
# 2273  567.0   51.0   6.0   4.666667  7.166667  5.866667       4.0
# 2274  662.0   87.0   8.0   3.666667  3.833333  6.000000       4.0
#
#                   REC_AVA_1              REC_AVA_2              REC_AVA_3  \
# 0                       NaN                    NaN                    NaN
# 1                       NaN                    NaN                    NaN
# 2                       NaN                    NaN                    NaN
# 3                       NaN                    NaN                    NaN
# 4                       NaN                    NaN                    NaN
# ...                     ...                    ...                    ...
# 2270  Mantido na Fase atual      Promovido de Fase  Mantido na Fase atual
# 2271  Mantido na Fase atual      Promovido de Fase  Mantido na Fase atual
# 2272      Promovido de Fase      Promovido de Fase                    NaN
# 2273  Mantido na Fase atual  Mantido na Fase atual      Promovido de Fase
# 2274      Promovido de Fase  Mantido na Fase atual      Promovido de Fase
#
#                     REC_AVA_4 INDICADO_BOLSA
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN            NaN
# 3                         NaN            NaN
# 4                         NaN            NaN
# ...                       ...            ...
# 2270                      NaN            Não
# 2271                      NaN            Não
# 2272                      NaN            Não
# 2273        Promovido de Fase            Não
# 2274  Mantido na Fase + Bolsa            Sim
#
# [2275 rows x 43 columns]

# %%
tabela_presenca
# Out:
# Ano         2020  2021  2022  anos_no_programa
# NOME
# ALUNO-1      1.0   1.0   0.0                 2
# ALUNO-10     1.0   0.0   0.0                 1
# ALUNO-100    1.0   1.0   1.0                 3
# ALUNO-1000   0.0   0.0   1.0                 1
# ALUNO-1001   0.0   1.0   1.0                 2
# ...          ...   ...   ...               ...
# ALUNO-995    0.0   1.0   1.0                 2
# ALUNO-996    1.0   1.0   1.0                 3
# ALUNO-997    1.0   1.0   1.0                 3
# ALUNO-998    0.0   0.0   1.0                 1
# ALUNO-999    1.0   1.0   0.0                 2
#
# [1348 rows x 4 columns]

# %%
# Criar uma tabela que mostra em quais anos cada aluno esteve presente
tabela_presenca = df_merged.pivot_table(index="NOME", columns="Ano", values="INDE", aggfunc="count").fillna(0)

# Contar quantos anos cada aluno esteve presente
tabela_presenca["anos_no_programa"] = (tabela_presenca > 0).sum(axis=1)

# Alunos que saíram do programa (estavam em 2020 ou 2021, mas não em 2022)
alunos_desistentes = tabela_presenca[(tabela_presenca[2022] == 0) & (tabela_presenca["anos_no_programa"] > 1)]

print("Alunos que podem ter desistido:")
print(alunos_desistentes)
# Out:
# Alunos que podem ter desistido:
# Ano         2020  2021  2022  anos_no_programa
# NOME
# ALUNO-1      1.0   1.0   0.0                 2
# ALUNO-1007   1.0   1.0   0.0                 2
# ALUNO-1016   1.0   1.0   0.0                 2
# ALUNO-1027   1.0   1.0   0.0                 2
# ALUNO-1035   1.0   1.0   0.0                 2
# ...          ...   ...   ...               ...
# ALUNO-951    1.0   1.0   0.0                 2
# ALUNO-965    1.0   1.0   0.0                 2
# ALUNO-973    1.0   1.0   0.0                 2
# ALUNO-986    1.0   1.0   0.0                 2
# ALUNO-999    1.0   1.0   0.0                 2
#
# [141 rows x 4 columns]
